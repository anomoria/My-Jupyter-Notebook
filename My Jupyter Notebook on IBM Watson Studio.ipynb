# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Anna Burch** Student

# %% [markdown]
# _I am interested in data science because I find it fascinating how many insights can be derived from quantitative and qualitative information. I am keen to learn how to explore how human behavior impacts our environment._

# %% [markdown]
# ### Multiply two by four

# %%
2*4
# Out:
# 8

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>
#
# ***
#
# [Click me to reach Google](www.google.com)
#
# ---
#
# My Favorite Food Items:
# 1. Fruit smoothies
# 2. Papayas
# 3. Sprouted coconuts
#
# My Favorite Places:
#   * Munich
#   * Paris
#   * Hawai'i
#
# ___
#
# Name | Age | Gender
# :---: | :---: | :---:
# Tobi | 33 | Male
# Erik | 29 | Male
# Tiffany | 30 | Female
#
# ___
#
# `I am practicing code and syntax highlighting. These back ticks work with Inline.`
#
# I don't understand what this next coding does or means. If anyone has ideas, I'd love the feedback.
# ~~help me please~~
#
# ```python
# s = "Python syntax highlighting"
# print s
# ```
# ___
#
# `I am also curious if images can only be added here through GitHub. Can someone explain this process to me? Thank you.`
